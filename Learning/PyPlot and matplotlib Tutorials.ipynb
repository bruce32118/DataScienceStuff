# %% [markdown]
# # Basic Plotting

# %%
# In IPython, use of the magic command "%matplotlib inline" causes 
# all plots to be inserted inline into the notebook:
# %matplotlib inline

# %%
# Import pyplot plotting library.
import matplotlib.pyplot as plt
# Import numpy numerical computing library
import numpy as np

# %% [markdown]
# <code>matplotlib.pyplot</code> is a collection of command style functions that make <code>matplotlib</code> work like MATLAB. Each <code>pyplot</code> function makes some change to a figure: eg, create a figure, create a plotting area in a figure, plot some lines in a plotting area, decorate the plot with labels, etc.... <code>matplotlib.pyplot</code> is stateful, in that it keeps track of the current figure and plotting area, and the plotting functions are directed to the current axes:

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
x = np.array([1,2,3,4])
y = x**2
plt.plot(x,y,color='red',marker='o')
plt.axis([x.min()-1,x.max()+1,y.min()-1,y.max()+1])
plt.show()

# %% [markdown]
# If matplotlib were limited to working with lists, it would be fairly useless for numeric processing. Generally, you will use numpy arrays. In fact, all sequences are converted to numpy arrays internally. The example below illustrates a plotting several lines with different format styles in one command using arrays.

# %%
# evenly sampled time at 250ms intervals
t = np.arange(-5.0, 5.0, 0.25)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
def hailstone(n):
    """Returns the length of the hailstone sequence for n."""
    i = 0
    while n > 1:
        i+=1
        if n % 2 == 0:
            n = int(n/2)
        else:
            n = int(3 * n + 1)
    return i+1

x = np.arange(1,10000,1)
hailstone = np.vectorize(hailstone) # Vectorize the function
y = hailstone(x)
plt.plot(x,y,'.',markersize=1)
plt.xlabel('n')
plt.ylabel('Length of n\'s Hailstone sequence')
plt.title('Hailstone sequence')
plt.show()

# %% [markdown]
# # Controlling Line Properties

# %% [markdown]
# Lines have many attributes that you can set: linewidth, dash style, antialiased, etc; see <code>matplotlib.lines.Line2D</code>. There are several ways to set line properties

# %%
# Using keyword args:
x = np.arange(0,4,0.1) # x = [0,0.1,0.2,...,3.9,4.0]
y = np.exp(x) # y = e^x
plt.plot(x,y,linewidth = 2.0)
plt.show()

# %%
# Use the setter methods of the Line2D instance. plot returns a list of lines; eg line1, line2 = plot(x1,y1,x2,y2). 
# Below I have only one line so it is a list of length 1. 
# I use tuple unpacking in the line, = plot(x, y, 'o') to 
# get the first element of the list:
line, = plt.plot(x,y,'-')
line.set_antialiased(False) # turn off antialiasing
plt.show()

# %%
# Use the setp() command. The example below uses a MATLAB-style command to 
# set multiple properties on a list of lines. 
# setp works transparently with a list of objects or a single object. 
# You can either use python keyword arguments or MATLAB-style string/value pairs:
x1, x2 = np.arange(0,4,0.1), np.arange(0,4,0.1)
y1, y2 = np.exp(x1), np.pi**x2
lines1 = plt.plot(x1,y1)
lines2 = plt.plot(x2,y2)

# use keyword args:
plt.setp(lines1,color='red',linewidth=2.0)
# or use MATLAB style string-value pairs:
plt.setp(lines2,'color','blue','linewidth','2.0')
plt.show()

# %% [markdown]
# # Figures and Axes

# %% [markdown]
# MATLAB, and pyplot, have the concept of the current figure and the current axes. All plotting commands apply to the current axes. The function <code>gca()</code> returns the current axes (a <code>matplotlib.axes.Axes</code> instance), and <code>gcf()</code> returns the current figure (<code>matplotlib.figure.Figure</code> instance). Normally, you don’t have to worry about this, because it is all taken care of behind the scenes. Below is a script to create two subplots.

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# You can create multiple figures by using multiple figure() calls with an increasing figure number. Of course, each figure can contain as many axes and subplots as your heart desires:

# %%
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1,2,3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4,5,6])


plt.figure(2)                # a second figure
plt.plot([4,5,6])            # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1,2,3')   # subplot 211 title

# %% [markdown]
# # Working with Text

# %% [markdown]
# The text() command can be used to add text in an arbitrary location, and the xlabel(), ylabel() and title() are used to add text in the indicated locations (see Text introduction for a more detailed example)

# %%
mu, sigma = 100, 15
x = (mu + sigma * np.random.randn(10000)) # 100 samples from Normal(mu,sigma)

# Histogram data
n,bins, patches = plt.hist(x,50, normed=1, facecolor='green',alpha=0.75)

plt.xlabel("Smarts")
plt.ylabel("Probability")
plt.title("Histogram of IQ")
plt.text(60,0.027,r'$\mu=100,\ \sigma=15$')
plt.axis([40,160,0,0.03])
plt.grid(True)
plt.show()

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', 
    xy=(3, 1), # Coordinates of arrow tip
    xytext=(1.5, 1.5), # coordinates of text, arrow orientation inferred.
    arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
plt.show()

# %% [markdown]
# ### Contour Plots

# %%
import matplotlib.mlab as mlab
x = np.arange(-5,5,0.1)
y = np.arange(-5,5,0.1)
X,Y = np.meshgrid(x,y)
Z = mlab.bivariate_normal(
    X,Y,
    sigmax = 1.0, sigmay = 1.0,
    mux = 0.0, muy = 0.0,
    sigmaxy = 0.0
)

plt.figure()
CS = plt.contour(X,Y,Z,colors='k')

# %% [markdown]
# ### Vector Plotting

# %% [markdown]
# This is a bit of an ad-hoc solution, as matplotlib does not possess an easy built-in method of plotting individual vectors.

# %%
x = np.array([0,1])
y = np.array([1,0])
x_plus_y = x+y

vectors = np.array([x,y,x_plus_y])
X_component,Y_component = zip(*vectors)
plt.quiver(
    np.zeros(len(vectors)),
    np.zeros(len(vectors)),
    X_component,
    Y_component,
    angles='xy',scale_units='xy',scale=1
)
plt.xlim([-1,5])
plt.ylim([-1,5])
plt.draw()
plt.show()

# %% [markdown]
# # 3D Plotting

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')

# %% [markdown]
# ### Line Plots

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')

pi, sin, cos = np.pi, np.sin, np.cos

theta = np.linspace(-4*pi, 4*pi,100)
z = np.linspace(0,1,100)
r = z
x = r*sin(theta)
y = r*cos(theta)
ax.plot(x,y,z,label='parametric curve')
ax.legend()
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
from mpl_toolkits.mplot3d import Axes3D
# Plot 1000 points on the surface of a sphere.

n = 1000
radius = 10
# Create random points on the surface of a sphere in spherical coordinates.
r = np.full(n,radius) # fixed radius
theta = np.pi*np.random.random(n) # rand in [0,pi]
phi = 2*np.pi*np.random.random(n) # rand in [0,2pi]

# Convert to Cartesian
x = r*np.sin(theta)*np.cos(phi)
y = r*np.sin(theta)*np.sin(phi)
z = r*np.cos(theta)

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x,y,z,color='b',marker='.')
plt.show()

# %% [markdown]
# ### Wireframe Surface Plots

# %%
from matplotlib import cm # for colormaps
x = np.linspace(-10,10,25)
y = np.linspace(-10,10,25)
xx,yy = np.meshgrid(x,y)
zz = -(xx**2 + yy**2)

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_wireframe(xx,yy,zz)
plt.show()

# %%
from matplotlib import cm
fig = plt.figure()
ax = fig.gca(projection='3d')
x = np.arange(-5,5,0.05)
y = np.arange(-5,5,0.05)
X,Y = np.meshgrid(x,y)
Z = mlab.bivariate_normal(
    X,Y,
    sigmax = 2.0, sigmay = 3.0,
    mux = 0.0, muy = 0.0,
    sigmaxy = 0.9
)
ax.plot_surface(X,Y,Z,alpha=0.3)
cset = ax.contourf(X,Y,Z,zdir='z',offset = Z.min(),cmap=cm.coolwarm)
cset = ax.contourf(X,Y,Z,zdir='x',offset = X.min(),cmap=cm.coolwarm)
cset = ax.contourf(X,Y,Z,zdir='y',offset = Y.max(),cmap=cm.coolwarm)


ax.set_xlabel(r'$X$')
ax.set_ylabel(r'$Y$')
ax.set_zlabel(r'$P\left(\mathcal{N}\left(X,Y\right)\right)$')
ax.zaxis._axinfo['label']['space_factor'] *= 1.2 #increase z-label padding
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
ax.set_zlim(-1.5*Z.min(),Z.max())
plt.show()
